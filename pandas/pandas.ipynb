# %%
import pandas as pd

# %%
#Задание 1
data = pd.read_csv('ratings.csv')
data.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
# 5       1     1088     4.0  1147868495
# 6       1     1175     3.5  1147868826
# 7       1     1217     3.5  1147878326
# 8       1     1237     5.0  1147868839
# 9       1     1250     4.0  1147868414

# %%
data[data['rating'] == 5.0]['movieId'].value_counts().head()
# Out:
# 318     39553
# 296     32169
# 356     25918
# 260     25804
# 2571    25482
# Name: movieId, dtype: int64

# %%
#Задание 2
power = pd.read_csv('power.csv', sep = ',')
power.head(10)
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1
# 5  Belgium  2011      25.0         1
# 6  Belgium  2010      22.0         1
# 7  Belgium  2009      45.0         1
# 8  Czechia  1998       1.0         1
# 9  Czechia  1995       7.0         1

# %%
power1 = power[(power['year'] >= 2005)&(power['year'] <= 2010)&(power['quantity'] >0)]
power2 = power1[(power1['category'] == 4)|(power1['category'] == 12)|(power1['category'] == 21)]
power3 = power2[(power2['country'] == 'latvian')|(power2['country'] == 'Lithuania')|(power2['country'] == 'Estonia')]
summ = power3['quantity'].sum()
print(summ)
# Out:
# 185736.0

# %%
#Задание 3
pd.read_html('https://fortrader.org/quotes', encoding='utf-8')
# Out:
# [                           Название   Цена  Изменение  Изменение(%)  Обновлено
#  0  EURRUB Курс евро к рублю сегодня  87.57      -0.40         -0.45        NaN
#  1       USDRUB Курс рубля к доллару  74.34      -0.32         -0.42        NaN,
#                                Название    Цена  Изменение  Изменение(%)  \
#  0       Нефть Brent Курс нефти сегодня   69.65       0.90          1.31
#  1          Нефть WTI Цены на нефть WTI   64.31      -2.30         -3.45
#  2  Природный газ Цена на природный газ    3.93       0.17          4.39
#  3                                 Кофе  165.40       8.65          5.52
#  4                             Кукуруза  571.60      15.60          2.81
#  5                                  Соя  364.20       3.20          0.89
#  6                               Хлопок   88.51       1.80          2.08
#
#     Обновлено
#  0        NaN
#  1        NaN
#  2        NaN
#  3        NaN
#  4        NaN
#  5        NaN
#  6        NaN  ,
# ...
